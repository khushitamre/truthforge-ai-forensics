# %% [markdown]
# # TRUTHFORGE model development
# This notebook documents the reproducible baseline. The executable training entry point is `../train_model.py`.

# %% [markdown]
# ## Workflow
# 1. Load and inspect the labeled question/response corpus.
# 2. Review class distribution and corpus limitations.
# 3. Engineer linguistic, semantic, entity, and numerical features.
# 4. Fit TF-IDF and a class-weighted Logistic Regression baseline.
# 5. Evaluate accuracy, precision, recall, F1, and ROC-AUC.
# 6. Review errors and save the final model bundle.

# %%
# %run ../train_model.py
